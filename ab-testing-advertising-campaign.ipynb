# %% [markdown]
# <a href="https://www.kaggle.com/code/bsrsrc/ab-testing-advertising-campaign?scriptVersionId=181541865" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div class="alert alert-primary" style="margin-top: 20px">
#
#
# <h1><center>AB Testing Advertising Campaign</center></h1>
#
# </div>

# %% [markdown]
# ![Açıklama](https://cdn.wmaraci.com/nedir/ab-testi.png)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
from scipy.stats import ttest_1samp, shapiro, levene, ttest_ind, mannwhitneyu, pearsonr, spearmanr, kendalltau, f_oneway, kruskal
from statsmodels.stats.proportion import proportions_ztest

df_control = pd.read_csv("/kaggle/input/ab-testing-dataset/control_group.csv", sep=";")
df_test = pd.read_csv("/kaggle/input/ab-testing-dataset/test_group.csv", sep=";")
df_control.head()
df_test.head()
# Out:
#    Campaign Name       Date  Spend [USD]  # of Impressions  Reach  \
# 0  Test Campaign  1.08.2019         3008             39550  35820
# 1  Test Campaign  2.08.2019         2542            100719  91236
# 2  Test Campaign  3.08.2019         2365             70263  45198
# 3  Test Campaign  4.08.2019         2710             78451  25937
# 4  Test Campaign  5.08.2019         2297            114295  95138
#
#    # of Website Clicks  # of Searches  # of View Content  # of Add to Cart  \
# 0                 3038           1946               1069               894
# 1                 4657           2359               1548               879
# 2                 7885           2572               2367              1268
# 3                 4216           2216               1437               566
# 4                 5863           2106                858               956
#
#    # of Purchase
# 0            255
# 1            677
# 2            578
# 3            340
# 4            768

# %%
df_control.shape
df_test.shape
# Out:
# (30, 10)
# (30, 10)

# %%
df_control.columns
df_test.columns
# Out:
# Index(['Campaign Name', 'Date', 'Spend [USD]', '# of Impressions', 'Reach',
#        '# of Website Clicks', '# of Searches', '# of View Content',
#        '# of Add to Cart', '# of Purchase'],
#       dtype='object')
# Index(['Campaign Name', 'Date', 'Spend [USD]', '# of Impressions', 'Reach',
#        '# of Website Clicks', '# of Searches', '# of View Content',
#        '# of Add to Cart', '# of Purchase'],
#       dtype='object')

# %%
df_control.isnull().sum()
df_test.isnull().sum()
# Out:
# Campaign Name          0
# Date                   0
# Spend [USD]            0
# # of Impressions       1
# Reach                  1
# # of Website Clicks    1
# # of Searches          1
# # of View Content      1
# # of Add to Cart       1
# # of Purchase          1
# dtype: int64
# Campaign Name          0
# Date                   0
# Spend [USD]            0
# # of Impressions       0
# Reach                  0
# # of Website Clicks    0
# # of Searches          0
# # of View Content      0
# # of Add to Cart       0
# # of Purchase          0
# dtype: int64

# %%
df_control["Spend [USD]"].mean()
df_control["# of Purchase"].mean()
df_test["Spend [USD]"].mean()
df_test["# of Purchase"].mean()
# Out:
# 2288.4333333333334
# 522.7931034482758
# 2563.0666666666666
# 521.2333333333333

# %%
plt.figure(figsize=(8,6))
plt.scatter(df_control["Spend [USD]"], df_control["# of Purchase"], color="red", alpha=0.5)
plt.title("Control Group")
plt.xlabel("Spend [USD]")
plt.ylabel("# of Purchase")
plt.show()
# Out:
# Text(0.5, 1.0, 'Control Group')
# Text(0.5, 0, 'Spend [USD]')
# Text(0, 0.5, '# of Purchase')

# %%
df_control.columns = [i+"_control" for i in df_control.columns]
df_test.columns =[i+"_test" for i in df_test.columns]
df_control.head()
df_test.head()
# Out:
#   Campaign Name_control Date_control  Spend [USD]_control  \
# 0      Control Campaign    1.08.2019                 2280
# 1      Control Campaign    2.08.2019                 1757
# 2      Control Campaign    3.08.2019                 2343
# 3      Control Campaign    4.08.2019                 1940
# 4      Control Campaign    5.08.2019                 1835
#
#    # of Impressions_control  Reach_control  # of Website Clicks_control  \
# 0                   82702.0        56930.0                       7016.0
# 1                  121040.0       102513.0                       8110.0
# 2                  131711.0       110862.0                       6508.0
# 3                   72878.0        61235.0                       3065.0
# 4                       NaN            NaN                          NaN
#
#    # of Searches_control  # of View Content_control  # of Add to Cart_control  \
# 0                 2290.0                     2159.0                    1819.0
# 1                 2033.0                     1841.0                    1219.0
# 2                 1737.0                     1549.0                    1134.0
# 3                 1042.0                      982.0                    1183.0
# 4                    NaN                        NaN                       NaN
#
#    # of Purchase_control
# 0                  618.0
# 1                  511.0
# 2                  372.0
# 3                  340.0
# 4                    NaN
#   Campaign Name_test  Date_test  Spend [USD]_test  # of Impressions_test  \
# 0      Test Campaign  1.08.2019              3008                  39550
# 1      Test Campaign  2.08.2019              2542                 100719
# 2      Test Campaign  3.08.2019              2365                  70263
# 3      Test Campaign  4.08.2019              2710                  78451
# 4      Test Campaign  5.08.2019              2297                 114295
#
#    Reach_test  # of Website Clicks_test  # of Searches_test  \
# 0       35820                      3038                1946
# 1       91236                      4657                2359
# 2       45198                      7885                2572
# 3       25937                      4216                2216
# 4       95138                      5863                2106
#
#    # of View Content_test  # of Add to Cart_test  # of Purchase_test
# 0                    1069                    894                 255
# 1                    1548                    879                 677
# 2                    2367                   1268                 578
# 3                    1437                    566                 340
# 4                     858                    956                 768

# %%
df = pd.concat([df_control, df_test], axis=1)
df.head()
# Out:
#   Campaign Name_control Date_control  Spend [USD]_control  \
# 0      Control Campaign    1.08.2019                 2280
# 1      Control Campaign    2.08.2019                 1757
# 2      Control Campaign    3.08.2019                 2343
# 3      Control Campaign    4.08.2019                 1940
# 4      Control Campaign    5.08.2019                 1835
#
#    # of Impressions_control  Reach_control  # of Website Clicks_control  \
# 0                   82702.0        56930.0                       7016.0
# 1                  121040.0       102513.0                       8110.0
# 2                  131711.0       110862.0                       6508.0
# 3                   72878.0        61235.0                       3065.0
# 4                       NaN            NaN                          NaN
#
#    # of Searches_control  # of View Content_control  # of Add to Cart_control  \
# 0                 2290.0                     2159.0                    1819.0
# 1                 2033.0                     1841.0                    1219.0
# 2                 1737.0                     1549.0                    1134.0
# 3                 1042.0                      982.0                    1183.0
# 4                    NaN                        NaN                       NaN
#
#    # of Purchase_control Campaign Name_test  Date_test  Spend [USD]_test  \
# 0                  618.0      Test Campaign  1.08.2019              3008
# 1                  511.0      Test Campaign  2.08.2019              2542
# 2                  372.0      Test Campaign  3.08.2019              2365
# 3                  340.0      Test Campaign  4.08.2019              2710
# 4                    NaN      Test Campaign  5.08.2019              2297
#
#    # of Impressions_test  Reach_test  # of Website Clicks_test  \
# 0                  39550       35820                      3038
# 1                 100719       91236                      4657
# 2                  70263       45198                      7885
# 3                  78451       25937                      4216
# 4                 114295       95138                      5863
#
#    # of Searches_test  # of View Content_test  # of Add to Cart_test  \
# 0                1946                    1069                    894
# 1                2359                    1548                    879
# 2                2572                    2367                   1268
# 3                2216                    1437                    566
# 4                2106                     858                    956
#
#    # of Purchase_test
# 0                 255
# 1                 677
# 2                 578
# 3                 340
# 4                 768

# %%
plt.hist(df["# of Purchase_control"])
plt.show()
# Out:
# (array([3., 2., 5., 1., 4., 2., 3., 2., 1., 6.]),
#  array([222. , 279.8, 337.6, 395.4, 453.2, 511. , 568.8, 626.6, 684.4,
#         742.2, 800. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["# of Purchase_test"])
plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b4536c54760>,
#   <matplotlib.lines.Line2D at 0x7b4536c544c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b4536c541f0>,
#   <matplotlib.lines.Line2D at 0x7b4536c55c90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b4536c54a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b4536c55f30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b4536c561d0>],
#  'means': []}

# %%
plt.hist(df["Spend [USD]_control"])
plt.show()
# Out:
# (array([5., 4., 3., 3., 4., 4., 2., 3., 1., 1.]),
#  array([1757. , 1889.6, 2022.2, 2154.8, 2287.4, 2420. , 2552.6, 2685.2,
#         2817.8, 2950.4, 3083. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["Spend [USD]_test"])
plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b45371402e0>,
#   <matplotlib.lines.Line2D at 0x7b453715d2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b45557094e0>,
#   <matplotlib.lines.Line2D at 0x7b4537142d70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b4537141c30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b4537140b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b45371428c0>],
#  'means': []}

# %% [raw]
# ---
# Define the hypothesis.
# ---
# * H0 = M1 = M2 (There is no statistically significant difference between control grop and test group.)
#
# * H1 = M1 != M2 (There is a statistically significant difference between control grop and test group.)
#
# ---

# %%
test_stat, pvalue = shapiro(df["# of Purchase_control"])
print("Test Stat = %.4f, p-value = %.4f" % (test_stat, pvalue))
# Out:
# Test Stat = nan, p-value = 1.0000

# %%
test_stat, pvalue = shapiro(df["# of Purchase_test"])
print("Test Stat = %.4f, p-value = %.4f" % (test_stat, pvalue))
# Out:
# Test Stat = 0.9182, p-value = 0.0241

# %% [markdown]
# ---
# * H0 = The normality assumption is met.
#
# * H1 = The normality assumption is not met.
# ---
# * p-value < 0.05, reject H0
#
# * p-value > 0.05, cannot reject H0.
# ---
#
# Since the p-value is smaller than 0.05, H0 can be rejected.
#
# ---

# %%
test_stat, pvalue = mannwhitneyu(df.loc[df["Campaign Name_control"] == "Control Campaign", "# of Purchase_control"],
                                 df.loc[df["Campaign Name_test"] == "Test Campaign", "# of Purchase_test"],
                                 nan_policy="omit")
print("Test Stat = %.4f, p-value = %.4f" % (test_stat, pvalue))
# Out:
# Test Stat = 439.0000, p-value = 0.9577
